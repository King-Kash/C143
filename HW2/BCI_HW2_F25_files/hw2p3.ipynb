# %% [markdown]
# ## Homework 2, Problem 3 on homogeneous Poisson processes
#
# ECE C143A/C243A, Fall Quarter 2025-26, Prof. J.C. Kao, TAs M.Y. Turali, S. Athreya

# %% [markdown]
# ## Background
#
# The goal of this notebook is to model a neuron as a homogeneous Poisson processes and evaluate its properties. We will consider a simulated neuron that has a cosine tuning curve described in equation (1.15) in *TN* (*TN* refers to *Theoretical Neuroscience* by Dayan and Abbott.)
#
# $$\lambda(s) = r_0 + (r_\text{max} - r_0)\cos(s-s_\text{max})$$
#
# where $\lambda$ is the firing rate (in spikes per second), $s$ is the reaching angle of the arm, $s_\text{max}$ is the reaching angle associated with the maximum response $r_\text{max}$, and $r_0$ is an offset that shifts the tuning curve up from the zero axis.  This will be refered as tuning equation in the following questions.
#
# Let $r_0=35$, $r_\text{max}=60$, and $s_\text{max}=\pi/2$.
#
# Note: If you are not as familiar with Python, be aware that if 1 is of type `int`, then 1 / a where a is any `int` greater than 1 will return 0, rather than a real number between 0 and 1.  This is because Python will return an `int` if both inputs are `int`s.  If instead you write 1.0 / a, you will get out the desired output, since 1.0 is of type `float`.

# %%
"""
ECE C143/C243 Homework-3 Problem-2

"""
import numpy as np
import matplotlib.pyplot as plt
import nsp as nsp # these are helper functions that we provide.
import scipy.special

# Load matplotlib images inline
# %matplotlib inline

# Reloading any code written in external .py files.
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### (a) (6 points) Spike trains
# For each of the following reaching condition ($s=k \cdot \pi/4$, where $k = 0,1,\ldots,7$), generate 100 spike trains  according to a homogeneous Poisson process. Each spike train should have a duration of 1 second.  You can think of each of each spike train sequence as a trial.  Therefore, we generate 100 trials of the neuron spiking according to a homogeneous Poisson Process for 8 reach directions.
#
# Your code for this section should populate a 2D `numpy` array, `spike_times` which has dimensions `num_cons` $\times$ `num_trials` (i.e., it is $8 \times 100$).  Each element of this 2D numpy array is a numpy array containing the spike times for the neuron on a given condition and trial.  Note that this array may have a different length for each trial.
#
# e.g., `spike_times.shape` should return `(8, 100)` and
# `spike_times[0,0]` should return the spike times on the first trial for a reach to the target at $0$ degrees.  In one instantiation, our code returns that `spike_times[0,0]` is:
#
# `array([   0.        ,    5.94436383,   10.85691999,   26.07821145,
#          50.02836141,   67.417219  ,   74.2948356 ,  119.19210112,
#         139.41789878,  176.59511596,  244.40788916,  267.3643421 ,
#         288.42590046,  324.3770265 ,  340.26911602,  407.75730065,
#         460.76250631,  471.23773964,  489.41659607,  514.60180131,
#         548.71822693,  565.6036432 ,  586.20557118,  601.11595447,
#         710.37485206,  751.60837895,  879.93536952,  931.26983289,
#         944.1130483 ,  949.38455374,  963.22509374,  964.67365483,
#         966.3865719 ,  974.3657882 ,  987.25729081])`
#
# Of course, this varies based off of random seed. Also note that time at 0 is not a spike.

# %%
## 2a
bin_width = 20                             # (ms)
s = np.arange(8)*np.pi/4                   # (radians)
num_cons = np.size(s)                       # num_cons = 8 in this case, number of directions
r_0 = 35 # (spikes/s)
r_max = 60 # (spikes/s)
s_max = np.pi/2 # (radians)
T = 1000 #trial length (ms)
num_trials = 100 # number of spike trains to generate

tuning = r_0 + (r_max-r_0)*np.cos(s-s_max) # tuning curve
spike_times = np.empty((num_cons, num_trials), dtype=list)

for con in range(num_cons):
    firing_rate = tuning[con]
    con_arr = []
    for rep in range(num_trials):
        #====================================================#
        # YOUR CODE HERE:
        #   Generate homogeneous Poisson process spike trains.
        #   You should populate the np.ndarray 'spike_times' according
        #   to the above description.
        #====================================================#
        # METHOD 2
        # lam = firing_rate * (T / 1000)
        # spike_count = np.random.poisson(lam)
        # spike_train = np.random.uniform(low=0, high=T, size=spike_count)

        spike_train = nsp.GeneratePoissonSpikeTrain(T, firing_rate)
        spike_times[con, rep] = spike_train
        print(len(spike_train))
        #====================================================#
        # END YOUR CODE
        #====================================================#
# Out:
# 32
# 37
# 27
# 35
# 37
# 36
# 36
# 31
# 36
# 34
# 29
# 32
# 25
# 35
# 30
# 38
# 37
# 31
# 33
# 27
# 41
# 42
# 27
# 34
# 38
# 36
# 33
# 40
# 33
# 33
# 35
# 36
# 41
# 33
# 30
# 35
# 22
# 43
# 38
# 34
# 36
# 40
# 26
# 35
# 29
# 40
# 50
# 44
# 41
# 45
# 38
# 30
# 36
# 38
# 30
# 35
# 32
# 40
# 34
# 35
# 46
# 27
# 31
# 41
# 32
# 37
# 47
# 41
# 33
# 33
# 39
# 29
# 40
# 38
# 36
# 38
# 38
# 26
# 36
# 42
# 39
# 31
# 45
# 37
# 30
# 33
# 38
# 50
# 31
# 41
# 30
# 44
# 47
# 38
# 29
# 32
# 25
# 26
# 37
# 25
# 51
# 47
# 39
# 47
# 55
# 53
# 56
# 45
# 50
# 61
# 42
# 62
# 47
# 50
# 53
# 58
# 55
# 71
# 47
# 48
# 49
# 53
# 49
# 65
# 45
# 47
# 50
# 58
# 48
# 47
# 53
# 51
# 58
# 62
# 56
# 56
# 51
# 41
# 53
# 59
# 45
# 51
# 65
# 55
# 56
# 39
# 51
# 54
# 60
# 50
# 54
# 52
# 54
# 43
# 55
# 47
# 60
# 47
# 56
# 51
# 57
# 44
# 61
# 68
# 47
# 67
# 50
# 63
# 53
# 59
# 47
# 49
# 56
# 59
# 56
# 61
# 62
# 45
# 52
# 55
# 55
# 55
# 58
# 51
# 62
# 43
# 46
# 53
# 43
# 50
# 49
# 58
# 56
# 61
# 54
# 45
# 52
# 51
# 49
# 41
# 61
# 67
# 66
# 49
# 58
# 50
# 69
# 78
# 58
# 67
# 61
# 67
# 66
# 63
# 61
# 56
# 56
# 60
# 58
# 53
# 69
# 69
# 38
# 60
# 68
# 62
# 66
# 63
# 69
# 60
# 58
# 53
# 39
# 55
# 62
# 61
# 54
# 70
# 58
# 60
# 45
# 66
# 77
# 64
# 67
# 50
# 67
# 50
# 58
# 56
# 62
# 64
# 74
# 69
# 62
# 52
# 58
# 63
# 55
# 65
# 51
# 65
# 63
# 59
# 64
# 81
# 53
# 54
# 59
# 61
# 59
# 52
# 63
# 68
# 56
# 70
# 62
# 54
# 55
# 48
# 71
# 62
# 68
# 61
# 65
# 63
# 42
# 67
# 65
# 76
# 62
# 73
# 55
# 54
# 65
# 59
# 54
# 55
# 70
# 53
# 47
# 54
# 45
# 56
# 47
# 51
# 54
# 50
# 53
# 49
# 43
# 45
# 59
# 49
# 54
# 54
# 42
# 65
# 57
# 58
# 48
# 42
# 56
# 46
# 51
# 59
# 51
# 62
# 52
# 48
# 62
# 60
# 58
# 60
# 58
# 46
# 48
# 55
# 53
# 55
# 65
# 42
# 50
# 45
# 51
# 49
# 49
# 55
# 53
# 66
# 60
# 53
# 51
# 60
# 47
# 46
# 57
# 70
# 47
# 55
# 42
# 51
# 61
# 46
# 46
# 57
# 46
# 55
# 58
# 45
# 61
# 54
# 51
# 57
# 53
# 51
# 47
# 55
# 49
# 52
# 41
# 58
# 60
# 56
# 62
# 48
# 57
# 56
# 69
# 51
# 48
# 48
# 56
# 56
# 55
# 59
# 56
# 38
# 44
# 63
# 31
# 44
# 29
# 31
# 43
# 33
# 41
# 35
# 30
# 35
# 37
# 37
# 35
# 48
# 24
# 35
# 36
# 32
# 35
# 40
# 47
# 34
# 48
# 45
# 28
# 34
# 40
# 36
# 30
# 32
# 36
# 32
# 40
# 36
# 39
# 34
# 33
# 44
# 39
# 32
# 38
# 52
# 51
# 32
# 38
# 34
# 36
# 35
# 36
# 37
# 35
# 33
# 32
# 44
# 25
# 39
# 32
# 42
# 27
# 41
# 26
# 33
# 44
# 38
# 37
# 31
# 28
# 32
# 42
# 47
# 37
# 33
# 44
# 46
# 27
# 39
# 33
# 33
# 28
# 33
# 37
# 36
# 32
# 37
# 36
# 28
# 47
# 42
# 31
# 36
# 44
# 34
# 42
# 41
# 37
# 37
# 51
# 38
# 23
# 35
# 13
# 15
# 18
# 23
# 25
# 24
# 14
# 16
# 21
# 21
# 20
# 15
# 21
# 18
# 19
# 20
# 17
# 16
# 24
# 22
# 22
# 19
# 14
# 14
# 20
# 19
# 17
# 17
# 15
# 17
# 26
# 20
# 15
# 23
# 17
# 14
# 17
# 12
# 16
# 14
# 17
# 19
# 18
# 16
# 20
# 19
# 24
# 18
# 19
# 27
# 20
# 30
# 21
# 16
# 21
# 20
# 20
# 18
# 22
# 20
# 18
# 20
# 23
# 19
# 15
# 18
# 18
# 13
# 19
# 22
# 19
# 14
# 20
# 24
# 14
# 23
# 18
# 22
# 19
# 12
# 19
# 26
# 18
# 19
# 17
# 25
# 14
# 20
# 17
# 15
# 14
# 15
# 17
# 19
# 24
# 17
# 17
# 14
# 19
# 18
# 10
# 14
# 10
# 11
# 12
# 8
# 6
# 12
# 10
# 10
# 9
# 12
# 13
# 5
# 14
# 13
# 8
# 13
# 20
# 14
# 14
# 8
# 14
# 10
# 8
# 9
# 6
# 10
# 16
# 10
# 8
# 12
# 11
# 11
# 16
# 8
# 16
# 13
# 9
# 8
# 6
# 14
# 17
# 8
# 12
# 14
# 11
# 18
# 12
# 10
# 13
# 16
# 12
# 9
# 11
# 4
# 18
# 8
# 7
# 14
# 10
# 17
# 10
# 8
# 16
# 9
# 11
# 11
# 11
# 10
# 11
# 11
# 8
# 14
# 14
# 10
# 9
# 9
# 8
# 16
# 20
# 12
# 9
# 9
# 16
# 15
# 10
# 11
# 17
# 11
# 9
# 10
# 13
# 8
# 7
# 10
# 12
# 4
# 13
# 8
# 14
# 26
# 16
# 16
# 14
# 22
# 12
# 13
# 19
# 21
# 23
# 21
# 12
# 22
# 18
# 23
# 17
# 14
# 23
# 13
# 24
# 17
# 20
# 21
# 24
# 20
# 20
# 14
# 22
# 15
# 10
# 17
# 20
# 12
# 19
# 20
# 17
# 18
# 17
# 19
# 24
# 21
# 14
# 15
# 19
# 25
# 20
# 16
# 27
# 17
# 15
# 17
# 17
# 18
# 21
# 9
# 26
# 23
# 16
# 16
# 12
# 12
# 20
# 20
# 10
# 22
# 24
# 22
# 15
# 18
# 15
# 12
# 15
# 19
# 19
# 24
# 13
# 18
# 22
# 23
# 18
# 16
# 17
# 18
# 19
# 17
# 11
# 23
# 21
# 18
# 20
# 17
# 23
# 8
# 19
# 15
# 17
# 13
# 15
# 28

# %%
s_labels = ['0', '$\pi$/4', '$\pi$/2', '3$\pi$/4', '$\pi$', '5$\pi$/4', '3$\pi$/2', '7$\pi$/4']
num_plot_rows = 5
num_plot_cols = 3
subplot_indx = [9, 6, 2, 4, 7, 10, 14, 12]
num_rasters_to_plot = 5 # per condition

# Generate and plot homogeneous Poisson process spike trains
plt.figure(figsize=(10,8))
for con in range(num_cons):

    # Plot spike rasters
    plt.subplot(num_plot_rows, num_plot_cols, subplot_indx[con])    
    nsp.PlotSpikeRaster(spike_times[con, 0:num_rasters_to_plot])
    
    plt.title('Spike trains, s= '+s_labels[con]+' radians')
    plt.tight_layout()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# /var/folders/cw/197yyjc956n9pn16fs3z00wm0000gn/T/ipykernel_1355/18819265.py:1: SyntaxWarning: invalid escape sequence '\p'
#   s_labels = ['0', '$\pi$/4', '$\pi$/2', '3$\pi$/4', '$\pi$', '5$\pi$/4', '3$\pi$/2', '7$\pi$/4']
# /var/folders/cw/197yyjc956n9pn16fs3z00wm0000gn/T/ipykernel_1355/18819265.py:1: SyntaxWarning: invalid escape sequence '\p'
#   s_labels = ['0', '$\pi$/4', '$\pi$/2', '3$\pi$/4', '$\pi$', '5$\pi$/4', '3$\pi$/2', '7$\pi$/4']
# /var/folders/cw/197yyjc956n9pn16fs3z00wm0000gn/T/ipykernel_1355/18819265.py:1: SyntaxWarning: invalid escape sequence '\p'
#   s_labels = ['0', '$\pi$/4', '$\pi$/2', '3$\pi$/4', '$\pi$', '5$\pi$/4', '3$\pi$/2', '7$\pi$/4']
# /var/folders/cw/197yyjc956n9pn16fs3z00wm0000gn/T/ipykernel_1355/18819265.py:1: SyntaxWarning: invalid escape sequence '\p'
#   s_labels = ['0', '$\pi$/4', '$\pi$/2', '3$\pi$/4', '$\pi$', '5$\pi$/4', '3$\pi$/2', '7$\pi$/4']
# /var/folders/cw/197yyjc956n9pn16fs3z00wm0000gn/T/ipykernel_1355/18819265.py:1: SyntaxWarning: invalid escape sequence '\p'
#   s_labels = ['0', '$\pi$/4', '$\pi$/2', '3$\pi$/4', '$\pi$', '5$\pi$/4', '3$\pi$/2', '7$\pi$/4']
# /var/folders/cw/197yyjc956n9pn16fs3z00wm0000gn/T/ipykernel_1355/18819265.py:1: SyntaxWarning: invalid escape sequence '\p'
#   s_labels = ['0', '$\pi$/4', '$\pi$/2', '3$\pi$/4', '$\pi$', '5$\pi$/4', '3$\pi$/2', '7$\pi$/4']
# /var/folders/cw/197yyjc956n9pn16fs3z00wm0000gn/T/ipykernel_1355/18819265.py:1: SyntaxWarning: invalid escape sequence '\p'
#   s_labels = ['0', '$\pi$/4', '$\pi$/2', '3$\pi$/4', '$\pi$', '5$\pi$/4', '3$\pi$/2', '7$\pi$/4']

# %% [markdown]
# ### Plotting the spike rasters.
#
# The following code plot 5 spike trains for each reaching angle in the same format as shown in Figure 1.6(A) in *TN*. You should take a look at this code to understand what it's doing.  You may also want to look at the `PlotSpikeRaster` function from `nsp`.
#
# The plots should make intuitive sense given the tuning parameters.

# %% [markdown]
# ### (b) (4 points) Plot spike histograms
#
# For each reaching angle, find the spike histogram by taking spike counts in non-overlapping 20 ms bins, then averaging across the 100 trials.  Plot the 8 resulting spike histograms around a circle, as in part (a).  This time, as we'll allow you to represent the data as you like, you will have to also plot each histogram on your own.  The spike histograms should have firing rate (in spikes / second) as the vertical axis and time (in msec, not time bin index) as the horizontal axis.
#
# Suggestion: you can use plt.bar to plot the histogram, it is important to set the `width` for this function, e.g. width = 12.

# %%
spike_times[0].shape
# Out:
# (100,)

# %%
## 2b

''' 
The key to coding this is realizing how the spikes are represented in each trial for each condition.
(refer to part a. problem statement)
Each spike is denoted by its time stamp!

(DO NOT PROCESS THE FIRST ELEMENT IN ANY GIVEN TRIAL AS IT WILL BE 0. A SPIKE DOES NOT HAPPEN AS T=0)
Define the window as a lower_bound and higher_bound (l_b + 20ms). Upper bound is not included.
    When moving the window just set l_b to h_b and h_b to again l_b + 20ms while h_b <= 1000ms

Count how many spikes in that window and add that count to the total for that window.

After repeating for all the trials in a condition, average for that window by dividing the count by the number of trials.

convert that average count to firing rate by dividing the count by the window size of 20ms.

'''

plt.figure(figsize=(10,8))

for con in range(num_cons):
    plt.subplot(num_plot_rows,num_plot_cols,subplot_indx[con])
    bin_count = int(T/20)
    segment_all = [0] * bin_count
    #====================================================#
    # YOUR CODE HERE:
    #   Generate and plot spike histogram for this condition
    #====================================================#
    for trial in spike_times[con]:
        l_b = 0
        h_b = bin_width
        segment = 0
        while h_b <= T:
            mask = (trial > l_b) & (trial <= h_b)
            window_total = np.sum(mask)
            segment_all[segment] += window_total
            l_b = h_b
            h_b = l_b + bin_width
            segment += 1
    print(segment_all)
    avg_count = np.array(segment_all) / num_trials
    print(avg_count)
    segment_rates = avg_count / (bin_width/1000)

    #Plotting
    bin_centers = np.linspace(bin_width/2, T-(bin_width/2), bin_count)
    plt.bar(bin_centers, segment_rates, width=(bin_width/2), color='blue', edgecolor='black', alpha=0.7)
    plt.ylim(0, r_max + (bin_width/2))
    plt.xlim(0, T)

    


    #====================================================#
    # END YOUR CODE
    #====================================================#
    plt.title('Spike trains, s= '+s_labels[con]+' radians')
    plt.tight_layout()
# Out:
# [np.int64(64), np.int64(69), np.int64(82), np.int64(77), np.int64(68), np.int64(66), np.int64(59), np.int64(67), np.int64(72), np.int64(75), np.int64(74), np.int64(68), np.int64(82), np.int64(67), np.int64(67), np.int64(72), np.int64(77), np.int64(71), np.int64(81), np.int64(68), np.int64(67), np.int64(73), np.int64(62), np.int64(60), np.int64(69), np.int64(70), np.int64(62), np.int64(61), np.int64(57), np.int64(70), np.int64(65), np.int64(75), np.int64(61), np.int64(64), np.int64(55), np.int64(65), np.int64(71), np.int64(62), np.int64(70), np.int64(67), np.int64(73), np.int64(75), np.int64(72), np.int64(72), np.int64(69), np.int64(65), np.int64(70), np.int64(62), np.int64(65), np.int64(79)]
# [0.64 0.69 0.82 0.77 0.68 0.66 0.59 0.67 0.72 0.75 0.74 0.68 0.82 0.67
#  0.67 0.72 0.77 0.71 0.81 0.68 0.67 0.73 0.62 0.6  0.69 0.7  0.62 0.61
#  0.57 0.7  0.65 0.75 0.61 0.64 0.55 0.65 0.71 0.62 0.7  0.67 0.73 0.75
#  0.72 0.72 0.69 0.65 0.7  0.62 0.65 0.79]
# [np.int64(92), np.int64(111), np.int64(109), np.int64(116), np.int64(108), np.int64(104), np.int64(97), np.int64(89), np.int64(97), np.int64(124), np.int64(100), np.int64(110), np.int64(111), np.int64(105), np.int64(104), np.int64(98), np.int64(105), np.int64(98), np.int64(104), np.int64(103), np.int64(100), np.int64(103), np.int64(116), np.int64(106), np.int64(109), np.int64(118), np.int64(97), np.int64(95), np.int64(113), np.int64(113), np.int64(82), np.int64(112), np.int64(96), np.int64(102), np.int64(91), np.int64(103), np.int64(85), np.int64(116), np.int64(104), np.int64(104), np.int64(90), np.int64(110), np.int64(94), np.int64(102), np.int64(107), np.int64(96), np.int64(104), np.int64(102), np.int64(116), np.int64(105)]
# [0.92 1.11 1.09 1.16 1.08 1.04 0.97 0.89 0.97 1.24 1.   1.1  1.11 1.05
#  1.04 0.98 1.05 0.98 1.04 1.03 1.   1.03 1.16 1.06 1.09 1.18 0.97 0.95
#  1.13 1.13 0.82 1.12 0.96 1.02 0.91 1.03 0.85 1.16 1.04 1.04 0.9  1.1
#  0.94 1.02 1.07 0.96 1.04 1.02 1.16 1.05]
# [np.int64(116), np.int64(120), np.int64(133), np.int64(115), np.int64(116), np.int64(127), np.int64(123), np.int64(111), np.int64(131), np.int64(122), np.int64(118), np.int64(108), np.int64(119), np.int64(132), np.int64(117), np.int64(98), np.int64(126), np.int64(113), np.int64(123), np.int64(129), np.int64(118), np.int64(134), np.int64(132), np.int64(115), np.int64(107), np.int64(120), np.int64(147), np.int64(112), np.int64(131), np.int64(108), np.int64(93), np.int64(105), np.int64(121), np.int64(123), np.int64(131), np.int64(97), np.int64(132), np.int64(124), np.int64(122), np.int64(101), np.int64(117), np.int64(112), np.int64(114), np.int64(132), np.int64(115), np.int64(110), np.int64(128), np.int64(135), np.int64(123), np.int64(123)]
# [1.16 1.2  1.33 1.15 1.16 1.27 1.23 1.11 1.31 1.22 1.18 1.08 1.19 1.32
#  1.17 0.98 1.26 1.13 1.23 1.29 1.18 1.34 1.32 1.15 1.07 1.2  1.47 1.12
#  1.31 1.08 0.93 1.05 1.21 1.23 1.31 0.97 1.32 1.24 1.22 1.01 1.17 1.12
#  1.14 1.32 1.15 1.1  1.28 1.35 1.23 1.23]
# [np.int64(112), np.int64(96), np.int64(82), np.int64(120), np.int64(106), np.int64(110), np.int64(109), np.int64(109), np.int64(105), np.int64(92), np.int64(101), np.int64(121), np.int64(101), np.int64(100), np.int64(81), np.int64(101), np.int64(86), np.int64(102), np.int64(109), np.int64(107), np.int64(127), np.int64(103), np.int64(109), np.int64(98), np.int64(91), np.int64(111), np.int64(109), np.int64(103), np.int64(103), np.int64(103), np.int64(100), np.int64(118), np.int64(91), np.int64(97), np.int64(115), np.int64(106), np.int64(100), np.int64(86), np.int64(109), np.int64(94), np.int64(101), np.int64(107), np.int64(124), np.int64(88), np.int64(127), np.int64(102), np.int64(116), np.int64(105), np.int64(85), np.int64(113)]
# [1.12 0.96 0.82 1.2  1.06 1.1  1.09 1.09 1.05 0.92 1.01 1.21 1.01 1.
#  0.81 1.01 0.86 1.02 1.09 1.07 1.27 1.03 1.09 0.98 0.91 1.11 1.09 1.03
#  1.03 1.03 1.   1.18 0.91 0.97 1.15 1.06 1.   0.86 1.09 0.94 1.01 1.07
#  1.24 0.88 1.27 1.02 1.16 1.05 0.85 1.13]
# [np.int64(60), np.int64(69), np.int64(83), np.int64(68), np.int64(78), np.int64(73), np.int64(73), np.int64(69), np.int64(67), np.int64(57), np.int64(72), np.int64(65), np.int64(67), np.int64(57), np.int64(72), np.int64(74), np.int64(70), np.int64(76), np.int64(79), np.int64(76), np.int64(73), np.int64(73), np.int64(90), np.int64(72), np.int64(72), np.int64(65), np.int64(74), np.int64(74), np.int64(68), np.int64(68), np.int64(77), np.int64(67), np.int64(62), np.int64(65), np.int64(72), np.int64(54), np.int64(75), np.int64(59), np.int64(66), np.int64(80), np.int64(82), np.int64(73), np.int64(87), np.int64(66), np.int64(71), np.int64(81), np.int64(60), np.int64(64), np.int64(74), np.int64(75)]
# [0.6  0.69 0.83 0.68 0.78 0.73 0.73 0.69 0.67 0.57 0.72 0.65 0.67 0.57
#  0.72 0.74 0.7  0.76 0.79 0.76 0.73 0.73 0.9  0.72 0.72 0.65 0.74 0.74
#  0.68 0.68 0.77 0.67 0.62 0.65 0.72 0.54 0.75 0.59 0.66 0.8  0.82 0.73
#  0.87 0.66 0.71 0.81 0.6  0.64 0.74 0.75]
# [np.int64(39), np.int64(38), np.int64(43), np.int64(29), np.int64(39), np.int64(34), np.int64(30), np.int64(32), np.int64(28), np.int64(41), np.int64(33), np.int64(30), np.int64(35), np.int64(35), np.int64(38), np.int64(35), np.int64(39), np.int64(31), np.int64(28), np.int64(31), np.int64(34), np.int64(38), np.int64(34), np.int64(37), np.int64(43), np.int64(42), np.int64(41), np.int64(28), np.int64(29), np.int64(40), np.int64(21), np.int64(33), np.int64(37), np.int64(43), np.int64(38), np.int64(33), np.int64(40), np.int64(21), np.int64(38), np.int64(49), np.int64(36), np.int64(24), np.int64(41), np.int64(37), np.int64(46), np.int64(28), np.int64(34), np.int64(40), np.int64(32), np.int64(44)]
# [0.39 0.38 0.43 0.29 0.39 0.34 0.3  0.32 0.28 0.41 0.33 0.3  0.35 0.35
#  0.38 0.35 0.39 0.31 0.28 0.31 0.34 0.38 0.34 0.37 0.43 0.42 0.41 0.28
#  0.29 0.4  0.21 0.33 0.37 0.43 0.38 0.33 0.4  0.21 0.38 0.49 0.36 0.24
#  0.41 0.37 0.46 0.28 0.34 0.4  0.32 0.44]
# [np.int64(19), np.int64(20), np.int64(15), np.int64(17), np.int64(25), np.int64(22), np.int64(17), np.int64(20), np.int64(22), np.int64(21), np.int64(24), np.int64(21), np.int64(21), np.int64(17), np.int64(24), np.int64(31), np.int64(20), np.int64(14), np.int64(20), np.int64(19), np.int64(17), np.int64(22), np.int64(22), np.int64(19), np.int64(30), np.int64(20), np.int64(23), np.int64(26), np.int64(24), np.int64(18), np.int64(15), np.int64(21), np.int64(12), np.int64(25), np.int64(31), np.int64(21), np.int64(27), np.int64(12), np.int64(12), np.int64(24), np.int64(17), np.int64(21), np.int64(16), np.int64(20), np.int64(16), np.int64(22), np.int64(17), np.int64(21), np.int64(16), np.int64(26)]
# [0.19 0.2  0.15 0.17 0.25 0.22 0.17 0.2  0.22 0.21 0.24 0.21 0.21 0.17
#  0.24 0.31 0.2  0.14 0.2  0.19 0.17 0.22 0.22 0.19 0.3  0.2  0.23 0.26
#  0.24 0.18 0.15 0.21 0.12 0.25 0.31 0.21 0.27 0.12 0.12 0.24 0.17 0.21
#  0.16 0.2  0.16 0.22 0.17 0.21 0.16 0.26]
# [np.int64(42), np.int64(25), np.int64(29), np.int64(43), np.int64(50), np.int64(40), np.int64(33), np.int64(32), np.int64(36), np.int64(41), np.int64(37), np.int64(29), np.int64(40), np.int64(27), np.int64(36), np.int64(36), np.int64(38), np.int64(41), np.int64(41), np.int64(38), np.int64(37), np.int64(37), np.int64(33), np.int64(36), np.int64(26), np.int64(35), np.int64(32), np.int64(26), np.int64(28), np.int64(27), np.int64(36), np.int64(30), np.int64(30), np.int64(28), np.int64(32), np.int64(24), np.int64(39), np.int64(34), np.int64(32), np.int64(38), np.int64(25), np.int64(46), np.int64(24), np.int64(37), np.int64(29), np.int64(37), np.int64(35), np.int64(41), np.int64(33), np.int64(28)]
# [0.42 0.25 0.29 0.43 0.5  0.4  0.33 0.32 0.36 0.41 0.37 0.29 0.4  0.27
#  0.36 0.36 0.38 0.41 0.41 0.38 0.37 0.37 0.33 0.36 0.26 0.35 0.32 0.26
#  0.28 0.27 0.36 0.3  0.3  0.28 0.32 0.24 0.39 0.34 0.32 0.38 0.25 0.46
#  0.24 0.37 0.29 0.37 0.35 0.41 0.33 0.28]

# %% [markdown]
# ### (c) (4 points)Tuning curve
#
# For each trial, count the number of spikes across the entire trial. Plots these points on the axes like shown in Figure 1.6(B) in *TN*, where the x-axis is reach angle and the y-axis is firing rate. There should be 800 points in the plot (but some points may be on top of each other due to the discrete nature of spike counts).  For each reaching angle, find the mean firing rate across the 100 trials, and plot the mean firing rate using a red point on the same plot.  Now, plot the tuning curve of this neuron in green on the same plot.

# %%
## 2c    
spike_counts = np.zeros((num_cons, num_trials)) # each element in spike_counts is the total spike count for this reach direction and trial 
#====================================================#
# YOUR CODE HERE:
#   Plot the single trial spike counts and the tuning curve
#   on top of each other.
#====================================================#
cond_rates_all = []
for con in range(num_cons):
    trial_rates = []
    for trial in spike_times[con]:
        rate = len(trial) / (T/1000)
        trial_rates.append(rate)
    cond_rates_all.append(trial_rates)
for con in range(num_cons):
    curr_angle = s[con]
    x = np.full_like(cond_rates_all[con], curr_angle)
    plt.scatter(x, cond_rates_all[con], color='blue', alpha=0.5)
mean_firing_rates = [np.mean(lst) for lst in cond_rates_all]
plt.scatter(s, mean_firing_rates, color='red')
plt.plot(s, tuning, color="green")
#====================================================#
# END YOUR CODE
#====================================================#
plt.xlabel('Reach angle (radians)')
plt.ylabel('Firing rate (spikes / second)')
plt.title('Simulated spike counts (blue)\n'+
           'mean simulated spike counts (red),and\n'+
           'cosine tuning curve used in simulation (green)')
plt.xlim(0, 2*np.pi)
# Out:
# (0.0, 6.283185307179586)

# %% [markdown]
# #### Question: Do the mean firing rates lie near the tuning curve?

# %% [markdown]
# #### Your answer:

# %% [markdown]
# ### (d) (5 points) Count distribution
# For each reaching angle, plot the *normalized* distribution
# (i.e., normalized so that the area under the distribution equals
# one) of spike counts (using the same counts from part (c)).  Plot
# the 8 distributions around a circle, as in part (a).  Fit a Poisson
# distribution to each empirical distribution and plot it on top of
# the corresponding empirical distribution.
#
# Please plot the empirical distribution as well as the fit

# %%
len(mean_firing_rates)
# Out:
# 8

# %%
##2d
'''
We are no longer talking about the firing rate here.

We are interested in seeing if the spike count is Poisson distributed. We need to shift focus to the Spike Counts now.
These plots indicate the probability distribution of the SPIKE COUNTS for each of the angles given its average firing rate (lambda).
AGAIN WE ARE NOT FOCUSING ON THE FIRING RATES!

'''
from scipy.stats import poisson

plt.figure(figsize=(10,8))
max_count = 0
for con in range(num_cons):
    plt.subplot(num_plot_rows,num_plot_cols,subplot_indx[con])

    spike_counts = [] #number of spikes for each trial in a given condition
    for trial in spike_times[con]:
        count = len(trial)
        spike_counts.append(count)
        if count > max_count:
            max_count = count
    
    #====================================================#
    # YOUR CODE HERE:
    #   Calculate the empirical mean for the Poisson spike
    #   counts, and then generate a curve reflecting the probability
    #   mass function of the Poisson distribution as a function
    #   of spike counts.
    #====================================================#
    bin_count = np.arange(-0.5, max_count+0.5, 1)
    k_vals = np.arange(0, max_count+1, 1)
    plt.hist(spike_counts, density=True, color='blue', alpha=0.7, bins=bin_count, )
    poission_param = mean_firing_rates[con]*(T/1000)
    poisson_graph_points = poisson.pmf(k_vals, poission_param)
    
    #====================================================#
    # END YOUR CODE
    #====================================================#
    
    #====================================================#
    # YOUR CODE HERE:
    #   Plot the empirical count distribution, and on top of it 
    #   plot your fit Poisson distribution.
    #====================================================#
    plt.plot(bin_count, poisson_graph_points, color='red')

    #====================================================#
    # END YOUR CODE
    #====================================================#
    plt.xlim([0, max_count])
    plt.title('Count distribution, s= '+ s_labels[con]+' radians')
    plt.tight_layout()

# %% [markdown]
# #### Question:
# Are the empirical distributions well-fit by Poisson distributions?

# %% [markdown]
# #### Your answer: Yes.

# %% [markdown]
# ### (e)(3 points) Fano factor
# For each reaching angle, find the mean and variance of the spike
# counts across the 100 trials (using the same spike counts from part
# (c)).  Plot the obtained mean and variance on the axes shown in
# Figure 1.14(A) in *TN*.  There should be 8 points in this plot
# -- one per reaching angle.

# %%
## 2e
#====================================================#
# YOUR CODE HERE:
#   Calculate and plot the mean and variance for each of
#   the 8 reaching conditions.  Mean should be on the 
#   x-axis and variance on the y-axis.
#====================================================#
mean_counts = mean_firing_rates
variance_counts = [np.var(lst) for lst in cond_rates_all]
plt.scatter(mean_counts, variance_counts)

FFone_x = [0, 75]
FFone_y = [0, 75]
plt.plot(FFone_x, FFone_y, color='red')
#====================================================#
# END YOUR CODE
#====================================================#

# %% [markdown]
# #### Question:
# Do these points lie near the 45 deg diagonal, as would be expected of a Poisson distribution?

# %% [markdown]
# #### Your answer: Yes.

# %% [markdown]
# ### (f) (4 points) Interspike interval (ISI) distribution
# For each reaching angle, plot the normalized distribution of
# ISIs. Plot the 8 distributions around a circle, as in part (a).  Fit
# an exponential distribution to each empirical distribution and plot
# it on top of the corresponding empirical distribution.
#
# Please plot the empirical distribution as well as the fit

# %%
## 2f
from scipy.stats import expon

plt.figure(figsize=(10,8))
max_count = 0
cond_ISIs = []
for con in range(num_cons) :
    plt.subplot(num_plot_rows,num_plot_cols,subplot_indx[con])

    
    #====================================================#
    # YOUR CODE HERE:
    #   Calculate the interspike interval (ISI) distribution
    #   by finding the empirical mean of the ISI's, which 
    #   is the inverse of the rate of the distribution.
    #====================================================#
    ISIs = []
    for trial in spike_times[con]:
        start = 0
        for i, time in enumerate(trial):
            ISIs.append(time - start)
            start = time
    print(ISIs)
    if np.max(ISIs) > max_count:
        max_count = np.max(ISIs)
    bin_count = 30
    ISIs = np.array(ISIs)
    counts, bins = np.histogram(ISIs, density=True, bins=bin_count)
    centers = 0.5*(bins[:-1] + bins[1:])
    plt.hist(ISIs, density=True, bins=bin_count)
    mean = np.mean(ISIs)
    expon_distr = expon.pdf(centers,loc=0, scale=mean)
    plt.plot(centers, expon_distr, color='red')
    cond_ISIs.append(ISIs)

    #====================================================#
    # END YOUR CODE
    #====================================================#  
    
    #====================================================#
    # YOUR CODE HERE:
    #   Plot Interspike interval (ISI) distribution
    #====================================================#

    #====================================================#
    # END YOUR CODE
    #====================================================#   
    plt.title('ISI distribution, s= '+ s_labels[con]+' radians')
    plt.tight_layout()
# Out:
# [np.float64(0.0), np.float64(28.699653457931362), np.float64(10.382302001041957), np.float64(19.30651619735739), np.float64(13.237821702329697), np.float64(25.691328250179566), np.float64(16.43956242360332), np.float64(34.922000483076005), np.float64(17.13234034000817), np.float64(105.58990488764641), np.float64(11.854974725296074), np.float64(24.74313094634448), np.float64(32.736312874541454), np.float64(1.9856937703937092), np.float64(15.80796773317843), np.float64(2.2885975503714917), np.float64(32.099543187120844), np.float64(11.003291166919837), np.float64(61.06151163415683), np.float64(46.368638654268295), np.float64(40.54214797300648), np.float64(43.02375522350701), np.float64(25.62105457555367), np.float64(30.902829193574235), np.float64(18.325781689921996), np.float64(77.9892336265874), np.float64(52.81946385422293), np.float64(16.250446097692816), np.float64(14.336597597400214), np.float64(3.368995932410712), np.float64(36.24118365857112), np.float64(48.623696447290854), np.float64(0.0), np.float64(5.140697666711865), np.float64(43.73644583001882), np.float64(15.37362318050642), np.float64(6.4782033095586655), np.float64(19.367638380737077), np.float64(7.900698344421727), np.float64(16.4046808976626), np.float64(16.19493527223426), np.float64(26.883769360032716), np.float64(13.933315509338087), np.float64(18.628085816550964), np.float64(5.464511416600061), np.float64(21.625558271940434), np.float64(4.151113779325158), np.float64(25.191794089768138), np.float64(105.57337487543106), np.float64(3.848110252831077), np.float64(26.45154702254655), np.float64(22.17606145387805), np.float64(46.31299525880581), np.float64(79.84376293101434), np.float64(7.998440692618715), np.float64(2.848574064160175), np.float64(40.05540565784497), np.float64(12.512343201440103), np.float64(116.70727331959029), np.float64(40.742228990280296), np.float64(19.668565969321094), np.float64(5.446119321903325), np.float64(4.736089773690196), np.float64(47.37213004238674), np.float64(63.97280589869251), np.float64(8.76203675345198), np.float64(23.064373020992548), np.float64(34.44857414332614), np.float64(26.409567663664347), np.float64(0.0), np.float64(26.61710594922168), np.float64(10.455507321126944), np.float64(35.23938227596116), np.float64(48.10400286852888), np.float64(11.182480124947801), np.float64(147.04730070031803), np.float64(0.7872537302658884), np.float64(51.72144586333809), np.float64(3.1713570714625803), np.float64(4.568182569380326), np.float64(35.925831834890175), np.float64(78.99032927072398), np.float64(11.457864817489394), np.float64(24.897570584559446), np.float64(37.8385478984012), np.float64(36.833912635727756), np.float64(60.041056829087324), np.float64(28.658603287383357), np.float64(20.623153814405782), np.float64(14.875181836425213), np.float64(27.471294689477304), np.float64(98.46477984266062), np.float64(50.930432786071265), np.float64(1.330073783654143), np.float64(63.65219947283765), np.float64(18.542978571194908), np.float64(0.0), np.float64(10.628721278879562), np.float64(52.31917656646283), np.float64(17.092828815978358), np.float64(9.102435127795843), np.float64(35.87128680572951), np.float64(17.336269197883922), np.float64(142.6754977364508), np.float64(31.54875949810463), np.float64(56.003584521735036), np.float64(24.252929497636217), np.float64(5.024484555878587), np.float64(9.768768501073737), np.float64(27.04509113705228), np.float64(35.45228628855352), np.float64(13.64668088385497), np.float64(18.1902826846337), np.float64(38.85715157224814), np.float64(40.00301297949318), np.float64(8.671949799062077), np.float64(20.736946298762064), np.float64(28.776657000485898), np.float64(117.52157775182718), np.float64(9.824467169940363), np.float64(9.296350908423392), np.float64(17.05689974331483), np.float64(12.537346606732058), np.float64(3.0507506253271686), np.float64(12.665462939683493), np.float64(0.3063250531978383), np.float64(35.686500430492856), np.float64(73.69745726419319), np.float64(2.052978016743964),  ...
# [np.float64(0.0), np.float64(53.288330141517), np.float64(7.92383456105955), np.float64(32.87090772694234), np.float64(57.91211474212582), np.float64(18.67418406981338), np.float64(8.23808427612991), np.float64(1.8847331609744344), np.float64(1.3644026142918335), np.float64(13.393044264965027), np.float64(19.87006750078268), np.float64(24.989904394896058), np.float64(1.7679495145482917), np.float64(30.112721706288283), np.float64(4.832137112414557), np.float64(19.906797665713327), np.float64(65.10205202974532), np.float64(8.10745499738141), np.float64(9.070932182707509), np.float64(15.014085476625894), np.float64(63.35047187724825), np.float64(0.16403280728815162), np.float64(8.236114676095383), np.float64(14.933050264129918), np.float64(80.1442122693229), np.float64(21.252325936071543), np.float64(19.275056791228053), np.float64(27.79871952206281), np.float64(5.303340881155918), np.float64(9.214404000781428), np.float64(14.535131447835738), np.float64(22.00899575143876), np.float64(10.487386974556216), np.float64(5.125149403388264), np.float64(22.93927209241008), np.float64(10.092252849986608), np.float64(0.567447927118792), np.float64(22.031095919312293), np.float64(42.26522200829038), np.float64(29.4326679281819), np.float64(18.551150760200926), np.float64(17.592630299731354), np.float64(15.332095162248493), np.float64(13.857386916202358), np.float64(8.391502608740666), np.float64(6.567748646176369), np.float64(1.7586543992445058), np.float64(34.10993146744772), np.float64(20.72753844913848), np.float64(31.726004711142878), np.float64(3.925012780033967), np.float64(0.0), np.float64(3.677884171693476), np.float64(12.615333014495745), np.float64(0.9478057040818335), np.float64(13.86975430273414), np.float64(8.157051651293639), np.float64(31.189904397098502), np.float64(15.10190613184919), np.float64(3.9602821697352795), np.float64(8.988811488696172), np.float64(73.01473524936769), np.float64(36.432448195028), np.float64(14.62751279272723), np.float64(28.52397492551316), np.float64(2.6697119637962032), np.float64(5.186681607685699), np.float64(56.17457940257714), np.float64(13.048548731453991), np.float64(12.398631017442199), np.float64(14.871532947730657), np.float64(51.5525950844559), np.float64(11.057030702279462), np.float64(26.13314233343135), np.float64(2.031069781902488), np.float64(19.31410607314473), np.float64(9.389246489441632), np.float64(24.057671766681608), np.float64(118.982020430163), np.float64(19.697719860263305), np.float64(22.41676844976996), np.float64(30.9981762924765), np.float64(7.614708489073678), np.float64(4.1752275208203855), np.float64(1.7622319758635285), np.float64(56.62099229294677), np.float64(1.964826902801974), np.float64(15.048844523013486), np.float64(2.2633560388799197), np.float64(48.027215591327604), np.float64(3.5359273663200383), np.float64(7.107599978562575), np.float64(6.194201254272684), np.float64(11.962880731222299), np.float64(13.928688352837867), np.float64(2.854531875442035), np.float64(20.150188273589833), np.float64(43.276014382544076), np.float64(0.0), np.float64(10.75772108174421), np.float64(22.000087596087063), np.float64(1.6938175338178993), np.float64(39.12465215412962), np.float64(15.395521877640888), np.float64(26.683783895115383), np.float64(2.242540155991094), np.float64(0.021125082378873117), np.float64(29.642081058117682), np.float64(34.10912353203551), np.float64(16.595153898725954), np.float64(1.3782411102165497), np.float64(5.185646259915444), np.float64(133.5863167817394), np.float64(30.87728926248957), np.float64(5.417044943349595), np.float64(35.92672667934812), np.float64(32.264216149342644), np.float64(28.76814128306262), np.float64(85.70523687126536), np.float64(70.12047960363986), np.float64(4.298797583658029), np.float64(26.993089334568822), np.float64(9.719513398427694), np.float64(19.826470648504255), np.float64(19.119254903461638), np.float64(22.599345199790037), np.float64(12.809082220118853), np.float64(32.879627335344594), np.float64(3.16615894570 ...
# [np.float64(0.0), np.float64(1.4724769126988961), np.float64(14.68397555991229), np.float64(0.3376083799800753), np.float64(32.50405239821271), np.float64(1.0428823113977614), np.float64(9.394005727986908), np.float64(1.5535004396320673), np.float64(5.019897022480258), np.float64(2.116588543378228), np.float64(9.617483730375184), np.float64(15.258978180021671), np.float64(5.960049808734325), np.float64(5.78903426538146), np.float64(6.003709754989771), np.float64(34.87806395433161), np.float64(4.298821961956662), np.float64(7.499560073596967), np.float64(18.48293673012904), np.float64(39.583666563023314), np.float64(67.55323623032763), np.float64(9.061968584740498), np.float64(0.5236582320786738), np.float64(25.203322826920044), np.float64(11.707958283769528), np.float64(6.349270699985823), np.float64(6.488094892395793), np.float64(23.047267011287772), np.float64(26.471365681159966), np.float64(28.21617192872185), np.float64(20.461133994208808), np.float64(19.598409781314047), np.float64(16.177658229305052), np.float64(17.55661193466983), np.float64(15.517465916760557), np.float64(96.57812516212152), np.float64(1.8080074956552608), np.float64(28.892950425329786), np.float64(30.468505780509872), np.float64(5.101935048113205), np.float64(13.583219564664546), np.float64(10.842847963046438), np.float64(1.0688413897529472), np.float64(29.274249120529703), np.float64(1.4276731113523056), np.float64(4.552638637124005), np.float64(13.732569593961216), np.float64(6.686008996547116), np.float64(13.876083068860225), np.float64(13.513028781510343), np.float64(23.333715548037617), np.float64(3.8083757345212916), np.float64(2.746536577612005), np.float64(25.466595129964276), np.float64(48.097468099324715), np.float64(24.063388270668156), np.float64(9.315292396797304), np.float64(6.7763994721620975), np.float64(20.422386947376935), np.float64(0.7374974122897129), np.float64(28.13146155997947), np.float64(0.0), np.float64(8.12019566341968), np.float64(7.023996342019592), np.float64(8.708257113597398), np.float64(0.6335187431210869), np.float64(15.351983437834484), np.float64(1.4132249658653535), np.float64(7.120614810457873), np.float64(23.40994439963054), np.float64(19.754113913001603), np.float64(19.252716174467935), np.float64(25.43524421182795), np.float64(1.5578308808190968), np.float64(69.40764974858126), np.float64(16.993817787719877), np.float64(14.799903793305504), np.float64(10.65162248799831), np.float64(15.656582646764747), np.float64(21.935558582121757), np.float64(18.746003558282496), np.float64(29.981320675312816), np.float64(32.44855792983668), np.float64(10.352369339451059), np.float64(6.363661395652741), np.float64(14.791891771023018), np.float64(28.812967517427694), np.float64(10.701535217283833), np.float64(9.590050851380681), np.float64(3.5518393332162645), np.float64(42.52171698857114), np.float64(17.770240821337268), np.float64(11.382737712791823), np.float64(9.01241409429963), np.float64(11.50421822416422), np.float64(5.506872936647255), np.float64(31.003039048283313), np.float64(14.842734569424238), np.float64(57.022308097931614), np.float64(9.932990411881974), np.float64(19.000113487739554), np.float64(0.41496518812709837), np.float64(28.765503684943724), np.float64(0.6605791209015024), np.float64(2.6127394525680074), np.float64(10.975811083287113), np.float64(3.3662714721817792), np.float64(3.007355298596167), np.float64(27.160314223848445), np.float64(7.909230339822557), np.float64(25.795056250979314), np.float64(14.83840230948556), np.float64(9.029037101503036), np.float64(23.731895059419458), np.float64(14.899224701418689), np.float64(14.765944035977554), np.float64(17.54261465148386), np.float64(4.510147202438134), np.float64(5.9269545188900565), np.float64(14.213750151045474), np.float64(1.8890639572779264), np.float64(0.1039370094330252), np.float64(11.661499902325318), np.float64(5.8674647587403115), np.float64(48.233236746951206), np.float64(3.12108734777496), np.float64(4.875090417777983), np.float64(6.41467 ...
# [np.float64(0.0), np.float64(36.91502896931917), np.float64(20.54020625871182), np.float64(26.961056527845145), np.float64(26.41081233059539), np.float64(4.737944286687508), np.float64(4.896832488984614), np.float64(11.005284190901037), np.float64(9.498686180572491), np.float64(37.63931185800715), np.float64(5.874484129347763), np.float64(48.9280835347231), np.float64(5.017181530284773), np.float64(0.16752874543030316), np.float64(21.419654578406607), np.float64(30.766945012485735), np.float64(1.2218717197239357), np.float64(58.29835593035472), np.float64(35.55059347956245), np.float64(20.223581926236363), np.float64(23.347597666180093), np.float64(3.3202890783258), np.float64(51.73536264580645), np.float64(6.742312068221565), np.float64(8.810157905278572), np.float64(19.861674777204826), np.float64(21.28252001428166), np.float64(3.9706427289760313), np.float64(5.3434660881714535), np.float64(27.51364518009177), np.float64(17.23396424708426), np.float64(7.6136033086270345), np.float64(15.543627370177433), np.float64(8.96316727591045), np.float64(33.77593471746468), np.float64(18.67787719840385), np.float64(37.279476260509), np.float64(65.28000305413946), np.float64(2.196935518874625), np.float64(22.64160016147116), np.float64(12.035341721340842), np.float64(36.34980976923805), np.float64(6.832486898792695), np.float64(0.15689670022140945), np.float64(8.204729781225865), np.float64(55.449073710443486), np.float64(56.9329483576696), np.float64(0.0), np.float64(5.858640650311573), np.float64(1.7952048105441225), np.float64(4.770585834816863), np.float64(20.835001568182296), np.float64(19.844910857576373), np.float64(8.845738723246463), np.float64(10.612368590494413), np.float64(19.77403766185681), np.float64(3.0044033968904387), np.float64(18.08085269995955), np.float64(35.157339134622674), np.float64(21.17355353080444), np.float64(24.762603205406066), np.float64(21.42629479197271), np.float64(12.908862254942534), np.float64(21.97433827565098), np.float64(16.27705722167599), np.float64(65.62140609162691), np.float64(3.9431368860973635), np.float64(22.328142628207956), np.float64(0.7753829399350138), np.float64(37.98181517050858), np.float64(17.578617961381042), np.float64(0.2143651306024026), np.float64(18.15339676781207), np.float64(40.2175148661035), np.float64(11.823892679934374), np.float64(5.154282782331848), np.float64(52.842378173719), np.float64(48.63797458276497), np.float64(7.7195385882810115), np.float64(7.3285562660393), np.float64(6.481285107420945), np.float64(24.149828704532183), np.float64(4.206592925556265), np.float64(31.17028642120306), np.float64(10.440635471112955), np.float64(8.976691823252622), np.float64(7.661576148930635), np.float64(27.379939735151197), np.float64(40.14412749845371), np.float64(8.678172259643816), np.float64(17.887903699777326), np.float64(17.98164481355002), np.float64(15.86752398845158), np.float64(3.5513535528142484), np.float64(0.5569983664659048), np.float64(17.440054666178867), np.float64(49.45758099237105), np.float64(24.691320983757123), np.float64(57.952456929725145), np.float64(1.1382520698637109), np.float64(5.092327356202986), np.float64(0.0), np.float64(15.75405089853298), np.float64(17.901227082265734), np.float64(40.1691276870679), np.float64(0.7415731070274063), np.float64(15.53137147868739), np.float64(11.172305429795031), np.float64(7.216269866798882), np.float64(17.95430679630455), np.float64(0.29710026034052817), np.float64(40.79393481319103), np.float64(27.32843424478034), np.float64(26.817434310052278), np.float64(12.465549729002277), np.float64(12.340153112435587), np.float64(117.14418424084636), np.float64(16.92394835330208), np.float64(27.542534396121596), np.float64(48.40351748395278), np.float64(8.458584889240683), np.float64(7.9909672274212085), np.float64(77.1141792333384), np.float64(16.612649936859725), np.float64(10.15712311655102), np.float64(46.868179516372834), np.float64(16.27043444152764), np.float64(2.689790721176223), np.float64(40.28177713426828),  ...
# [np.float64(0.0), np.float64(31.32202546201395), np.float64(19.313303271712616), np.float64(6.782918269460957), np.float64(28.369024960416276), np.float64(94.4910081106972), np.float64(45.98883290377026), np.float64(48.73362762574382), np.float64(19.9421902628348), np.float64(7.349391760355559), np.float64(49.40006340696215), np.float64(28.458886690519762), np.float64(5.972536371004594), np.float64(7.5159003315373525), np.float64(51.045037233535425), np.float64(4.692135902170719), np.float64(50.63702172743126), np.float64(44.230784791086876), np.float64(5.356808790069977), np.float64(0.18122007966860565), np.float64(82.18922571392352), np.float64(37.51467179571432), np.float64(97.02960812273307), np.float64(14.375438600530174), np.float64(18.207698726791364), np.float64(1.8788478155641997), np.float64(7.662558040212275), np.float64(39.755684444825306), np.float64(40.27350237956932), np.float64(9.401163897505967), np.float64(15.929768034013136), np.float64(0.0), np.float64(13.710252944225754), np.float64(3.9804200490608217), np.float64(28.13147178357162), np.float64(25.80286273022277), np.float64(30.249222004925016), np.float64(29.469835452862057), np.float64(50.80524546222384), np.float64(15.531601843579296), np.float64(19.953340231942832), np.float64(6.227593030412805), np.float64(47.719764963324195), np.float64(7.714398462452152), np.float64(1.1218708666494308), np.float64(6.29422304815165), np.float64(31.65857426853472), np.float64(1.8320058135020645), np.float64(63.49694509085538), np.float64(7.784234100641015), np.float64(4.246633952357342), np.float64(2.8837911571486075), np.float64(2.0121088704348153), np.float64(14.677885993329994), np.float64(30.460797230597223), np.float64(6.186867964497367), np.float64(7.913633857871162), np.float64(19.843561016975173), np.float64(17.61471908160405), np.float64(9.029392810921024), np.float64(6.626105984574679), np.float64(34.78059931176983), np.float64(42.8277551510879), np.float64(13.836538848064038), np.float64(11.489595713248605), np.float64(98.28138553397889), np.float64(60.53142957235025), np.float64(19.420834541096838), np.float64(33.002931801057684), np.float64(14.819534001771672), np.float64(15.216107248817138), np.float64(64.90617783078335), np.float64(4.810036201812409), np.float64(48.75411775114878), np.float64(12.358779481157853), np.float64(0.0), np.float64(53.541710322679556), np.float64(51.47732937629187), np.float64(7.309430796364779), np.float64(21.836478390919495), np.float64(0.6391976409613278), np.float64(40.08164444146442), np.float64(24.027255513733763), np.float64(12.840887339766965), np.float64(62.842349345211545), np.float64(63.76651931818304), np.float64(17.598306721262816), np.float64(3.7953890147035736), np.float64(9.65043120293376), np.float64(24.446935764366742), np.float64(16.940476438855455), np.float64(28.217820187531515), np.float64(5.622671512267345), np.float64(15.81752509008237), np.float64(92.63950512638036), np.float64(9.159677825256153), np.float64(14.488062397214321), np.float64(73.57724864668887), np.float64(11.616447367580577), np.float64(10.071674975195606), np.float64(175.08373383611388), np.float64(0.5461327207784734), np.float64(2.0737506722318813), np.float64(115.38537370557128), np.float64(0.0), np.float64(24.887196014032785), np.float64(45.58555817268477), np.float64(15.274948854471532), np.float64(48.45874099781085), np.float64(12.271048353418507), np.float64(22.603368475947633), np.float64(5.007875100911548), np.float64(35.18071900903246), np.float64(10.29344763393351), np.float64(18.82443476919022), np.float64(170.16491819081145), np.float64(36.96842636419541), np.float64(18.65974535139611), np.float64(1.4183087892743629), np.float64(15.831216290026873), np.float64(45.29818546981579), np.float64(76.81641251143935), np.float64(32.49527637415895), np.float64(18.28463078232369), np.float64(1.3193111314159296), np.float64(57.530390837456935), np.float64(22.472220503414746), np.float64(2.676755231943389), np.float64(35.43628360982541), ...
# [np.float64(0.0), np.float64(99.46659098818024), np.float64(14.46368778843771), np.float64(40.823436565181126), np.float64(42.80117148364661), np.float64(13.339642282471488), np.float64(197.50210641761416), np.float64(67.05760528943085), np.float64(15.986539204714177), np.float64(315.33214117259615), np.float64(110.01637074804864), np.float64(36.631962639596736), np.float64(5.681219150316679), np.float64(0.0), np.float64(15.364038279217954), np.float64(59.03332900346669), np.float64(0.3345632376983474), np.float64(119.67189857284599), np.float64(27.774371726844947), np.float64(52.73981459537089), np.float64(26.468688746833777), np.float64(168.84125089097444), np.float64(21.821758430795967), np.float64(17.035375336131324), np.float64(170.68682609280393), np.float64(73.3434303706506), np.float64(36.92534167508586), np.float64(203.37963291967094), np.float64(0.0), np.float64(24.99669079278842), np.float64(240.29574163849966), np.float64(78.84162187798051), np.float64(84.71857983969608), np.float64(34.952192820019945), np.float64(162.16696203918053), np.float64(92.91655796849932), np.float64(100.46331577061676), np.float64(11.210311388053924), np.float64(21.92904517255613), np.float64(20.507951476948733), np.float64(13.602459484363749), np.float64(41.056415366302986), np.float64(11.036625966173233), np.float64(24.47000516732703), np.float64(25.98152677859173), np.float64(7.238690267932725), np.float64(0.0), np.float64(55.28793196086282), np.float64(36.58030196453636), np.float64(5.618742333408775), np.float64(119.49911597133114), np.float64(56.0167404580863), np.float64(193.4296970420064), np.float64(34.57023361500342), np.float64(6.636162279612904), np.float64(5.737614135703723), np.float64(73.81864761755446), np.float64(68.2682044240006), np.float64(36.09178806417435), np.float64(64.68078429593629), np.float64(6.59556848038676), np.float64(0.7013065315866243), np.float64(4.663620688050287), np.float64(55.97129788671111), np.float64(3.0048957735197064), np.float64(29.398483806068043), np.float64(43.55995693773468), np.float64(11.744650411182988), np.float64(69.60636209724896), np.float64(0.0), np.float64(5.916571034144923), np.float64(25.807012875055143), np.float64(11.436460318169217), np.float64(14.042942619474402), np.float64(88.64943947327723), np.float64(63.730817742912365), np.float64(13.182944582126112), np.float64(44.541076513899725), np.float64(27.615687733714594), np.float64(1.7385384931292265), np.float64(105.0953177646777), np.float64(21.522883651369057), np.float64(123.17871415014446), np.float64(75.39846180589336), np.float64(40.870288182884906), np.float64(39.671836754594324), np.float64(27.149434994590933), np.float64(76.32541386020273), np.float64(37.41387380330616), np.float64(0.7792151500701721), np.float64(15.078400368347047), np.float64(5.948657636619828), np.float64(0.15936202550653888), np.float64(114.00122182736084), np.float64(0.0), np.float64(53.67403013694023), np.float64(71.45015912600041), np.float64(83.14955094687598), np.float64(36.34918469888211), np.float64(4.3921315611517855), np.float64(48.271809389490926), np.float64(4.72318459395899), np.float64(18.44121501303107), np.float64(1.5006131311594686), np.float64(18.824955630555053), np.float64(33.55030214495656), np.float64(39.31943722789157), np.float64(24.388319294684777), np.float64(58.6061726859777), np.float64(31.62423398124224), np.float64(21.4165195337323), np.float64(49.269754117405), np.float64(34.26492646792269), np.float64(123.3037289816773), np.float64(23.795056884582323), np.float64(18.67779664618388), np.float64(49.266471574458706), np.float64(97.47801633050096), np.float64(0.0), np.float64(22.001107327849944), np.float64(64.96790640213246), np.float64(168.09924685264042), np.float64(191.81842341336386), np.float64(110.00442190926333), np.float64(19.654098043711315), np.float64(76.12616662887046), np.float64(77.45412074438866), np.float64(5.139737890286028), np.float64(40.863537380629396), np.float64(58.238106456870014), np.float64(14 ...
# [np.float64(0.0), np.float64(252.32557956330086), np.float64(24.946971180479665), np.float64(227.392783587912), np.float64(6.508258301707883), np.float64(224.3392346333908), np.float64(13.360926398027004), np.float64(89.03367744633715), np.float64(6.015526549949527), np.float64(154.00814130349215), np.float64(0.0), np.float64(123.30000574030342), np.float64(103.52895093937698), np.float64(58.386215218316465), np.float64(21.36489328720154), np.float64(116.59522728265216), np.float64(65.16282665744632), np.float64(73.29835888859793), np.float64(100.93533650815937), np.float64(35.46932713948388), np.float64(9.324057469493141), np.float64(8.040269344692206), np.float64(7.391688395547476), np.float64(114.34851775198445), np.float64(0.0), np.float64(24.64288657596965), np.float64(108.3726667638134), np.float64(87.04769698625987), np.float64(357.8630928224846), np.float64(10.612931279846862), np.float64(42.075630889076024), np.float64(69.62800330570371), np.float64(92.51455255583994), np.float64(34.220437965554765), np.float64(0.0), np.float64(249.9794463358199), np.float64(73.58139026775791), np.float64(58.03540919866049), np.float64(97.99223341009713), np.float64(4.978440902885495), np.float64(16.24984072143593), np.float64(136.0746583216046), np.float64(136.8638412883032), np.float64(126.8378562576952), np.float64(52.543725013629114), np.float64(0.0), np.float64(137.5642227907377), np.float64(174.56391375986613), np.float64(164.29022999556128), np.float64(50.861291727604566), np.float64(5.635716626043404), np.float64(3.5384189239232455), np.float64(103.25790035718296), np.float64(18.839041687983695), np.float64(28.45713079789573), np.float64(20.207448889730244), np.float64(10.73381222079388), np.float64(0.0), np.float64(41.401780286724986), np.float64(159.47383408073017), np.float64(468.0431368034053), np.float64(200.0261719320896), np.float64(10.050768073068639), np.float64(20.21485030925976), np.float64(43.85592316260511), np.float64(0.0), np.float64(61.281299380736534), np.float64(148.51082947706954), np.float64(296.3930718319752), np.float64(127.15169102108518), np.float64(4.693188957347729), np.float64(0.0), np.float64(104.50140783464255), np.float64(30.92500652526715), np.float64(25.9034543086739), np.float64(249.2560099306369), np.float64(69.6620344613612), np.float64(80.4016417955778), np.float64(130.83620703135864), np.float64(29.59958101329289), np.float64(44.71338443474497), np.float64(55.530304063042536), np.float64(103.28411459476149), np.float64(0.0), np.float64(225.24472189760644), np.float64(212.00537209299108), np.float64(42.06517264200869), np.float64(19.84426680968147), np.float64(0.5990916889912228), np.float64(20.499513425086093), np.float64(95.09273065339278), np.float64(168.59755715548567), np.float64(70.3768594830035), np.float64(0.0), np.float64(16.42722952465553), np.float64(85.04532595556196), np.float64(54.91064747074293), np.float64(256.50234467561677), np.float64(263.153878758138), np.float64(96.75757288786929), np.float64(140.750474672706), np.float64(55.55944659484476), np.float64(27.282014531368418), np.float64(0.0), np.float64(127.36484670460639), np.float64(171.60462741018068), np.float64(104.46694085095567), np.float64(0.42406657376380963), np.float64(175.23282983101427), np.float64(69.44077798407159), np.float64(133.0805865934451), np.float64(181.04427166811308), np.float64(0.0), np.float64(123.64681896857623), np.float64(57.578470118392815), np.float64(177.49246441571353), np.float64(51.070634446151644), np.float64(175.21677469791524), np.float64(98.00983921114073), np.float64(5.333827098702727), np.float64(10.281555043196136), np.float64(53.08733639459092), np.float64(133.547166359843), np.float64(67.6149914950106), np.float64(0.0), np.float64(69.61594626983967), np.float64(20.178146837883475), np.float64(113.50219825229436), np.float64(207.85219146101866), np.float64(10.248561457629762), np.float64(9.537094086563513), np.float64(15.013609677571196), np.float64(41.84235228250952), np.float64( ...
# [np.float64(0.0), np.float64(111.63906814020496), np.float64(22.492798587234176), np.float64(77.99440130061825), np.float64(120.75704071293183), np.float64(61.523461247685304), np.float64(65.2279567180899), np.float64(45.998333782712734), np.float64(166.0606537843476), np.float64(3.7700474790572116), np.float64(1.9881532520149676), np.float64(69.07743957314926), np.float64(33.04536133280203), np.float64(106.88171183267366), np.float64(0.0), np.float64(87.36297864423352), np.float64(14.977486022328208), np.float64(47.369619834063315), np.float64(5.054725582643528), np.float64(3.705446005928991), np.float64(36.56338132083411), np.float64(33.21087923460641), np.float64(31.59598083257876), np.float64(14.361613266390123), np.float64(39.218832233582134), np.float64(46.53919658355824), np.float64(19.365460266706975), np.float64(36.53601382047515), np.float64(0.31281301552996865), np.float64(110.99764108932794), np.float64(0.022684368406657995), np.float64(74.3736037841303), np.float64(3.9948931676137818), np.float64(4.2103818226332805), np.float64(135.73909416349113), np.float64(55.161610448730585), np.float64(17.536793423006884), np.float64(54.18581776440749), np.float64(29.770628996490927), np.float64(33.06753336102588), np.float64(0.0), np.float64(23.62583268935996), np.float64(150.02064320662967), np.float64(21.783009948362235), np.float64(158.7399438568185), np.float64(22.560263145859096), np.float64(47.03056338059719), np.float64(53.08632593043433), np.float64(52.47851640679289), np.float64(72.18139240269488), np.float64(5.374497660392308), np.float64(80.65735973594224), np.float64(29.318747891672388), np.float64(146.17890949266484), np.float64(74.02796751294966), np.float64(30.612345384774358), np.float64(0.0), np.float64(22.76111235927168), np.float64(70.21596690926899), np.float64(103.23020184537698), np.float64(1.2719610392387892), np.float64(39.763775644782555), np.float64(56.98215309689709), np.float64(42.55410700123309), np.float64(49.62642158737714), np.float64(7.881635308567809), np.float64(59.685529715144014), np.float64(82.86739852389161), np.float64(110.06998209722587), np.float64(168.3424384598809), np.float64(71.10313022686921), np.float64(37.47496311692589), np.float64(0.0), np.float64(92.31195290142006), np.float64(16.016693168780904), np.float64(27.40723153799624), np.float64(11.626285590470559), np.float64(102.51564403456686), np.float64(2.7800983598667983), np.float64(76.07000311945126), np.float64(367.97043059376267), np.float64(20.519075289469356), np.float64(122.13855440484849), np.float64(45.85949461868961), np.float64(44.49876225512037), np.float64(18.692817396274677), np.float64(0.0), np.float64(42.31088433974607), np.float64(28.289810263225434), np.float64(23.704029580002796), np.float64(75.59325870652964), np.float64(5.962387481500912), np.float64(86.27829487830118), np.float64(97.78001548990483), np.float64(8.554238704868965), np.float64(11.80697026793348), np.float64(13.072612013703292), np.float64(49.405912546043055), np.float64(59.173266217786136), np.float64(21.55969431447477), np.float64(24.0557386286589), np.float64(78.28523146895145), np.float64(24.560441318477842), np.float64(14.453637529269258), np.float64(187.51404470445652), np.float64(64.06349203708942), np.float64(6.2181532905698305), np.float64(11.095943757272948), np.float64(0.0), np.float64(143.7791389546212), np.float64(103.78492249703439), np.float64(27.596938268747778), np.float64(190.8438332215224), np.float64(15.157813394120865), np.float64(116.89613873455147), np.float64(67.61889063572778), np.float64(26.52329726139112), np.float64(3.8529794964267694), np.float64(176.04086359830728), np.float64(74.55884009021406), np.float64(0.0), np.float64(66.64671912547486), np.float64(7.149469427036848), np.float64(119.25365909654208), np.float64(141.695718171914), np.float64(11.966418795457685), np.float64(65.85575371837479), np.float64(139.0800168636236), np.float64(70.82453057785096), np.float64(13.574741105103612), np.float64(50.45235079 ...

# %% [markdown]
# #### Question:
# Are the empirical distributions well-fit by exponential distributions?

# %% [markdown]
# #### Your answer: Yes.

# %% [markdown]
# ### (g) (4 points) Coefficient of variation ($C_V$)
#   For each reaching angle, find the average ISI and $C_V$ of the ISIs.
#   Plot the resulting values on the axes shown in Figure 1.16 in
#   *TN*.  There should be 8 points in this plot.

# %%
len(cond_ISIs)
# Out:
# 8

# %%
#2g
#====================================================#
# YOUR CODE HERE:
# Calculate and plot coeffcient of variation
#====================================================#
C_v = []
mean_isis = []
for con in range(num_cons):
    mean = np.mean(cond_ISIs[con])
    mean_isis.append(mean)
    std = np.std(cond_ISIs[con])
    C_v.append(std/mean)
    
plt.figure(figsize=(6,6))
plt.scatter(mean_isis, C_v)

#====================================================#
# END YOUR CODE
#====================================================#

# %% [markdown]
# #### Question:
# Do the $C_V$ values lie near unity, as would be expected of a Poisson process?

# %% [markdown]
# #### Your answer: Yes.
